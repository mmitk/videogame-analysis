# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
gamedata=pd.read_csv('./video_game.csv/video_game.csv')

# %%
gamedata.head()
# Out:
#    Unnamed: 0                      Name Platform  Year_of_Release  \
# 0           1                Wii Sports      Wii           2006.0
# 1           2         Super Mario Bros.      NES           1985.0
# 2           3            Mario Kart Wii      Wii           2008.0
# 3           4         Wii Sports Resort      Wii           2009.0
# 4           5  Pokemon Red/Pokemon Blue       GB           1996.0
#
#           Genre Publisher  NA_players  EU_players  JP_players  Other_players  \
# 0        Sports  Nintendo       41.36       28.96        3.77           8.45
# 1      Platform  Nintendo       29.08        3.58        6.81           0.77
# 2        Racing  Nintendo       15.68       12.76        3.79           3.29
# 3        Sports  Nintendo       15.61       10.93        3.28           2.95
# 4  Role-Playing  Nintendo       11.27        8.89       10.22           1.00
#
#    Global_players  Critic_Score  Critic_Count User_Score  User_Count  \
# ...

# %%
gamedata=gamedata.drop(columns=['Unnamed: 0'])

# %%
gamedata.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_players  EU_players  JP_players  Other_players  Global_players  \
# 0       41.36       28.96        3.77           8.45           82.53
# 1       29.08        3.58        6.81           0.77           40.24
# 2       15.68       12.76        3.79           3.29           35.52
# 3       15.61       10.93        3.28           2.95           32.77
# 4       11.27        8.89       10.22           1.00           31.37
#
#    Critic_Score  Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
gamedata.describe()
# Out:
#        Year_of_Release    NA_players    EU_players    JP_players  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#        Other_players  Global_players  Critic_Score  Critic_Count    User_Count
# count   16719.000000    16719.000000   8137.000000   8137.000000   7590.000000
# mean        0.047332        0.533543     68.967679     26.360821    162.229908
# std         0.186710        1.547935     13.938165     18.980495    561.282326
# ...

# %% [markdown]
# User_count has higher variance than other columns, What's the reason?

# %%
gamedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
# Name               16717 non-null object
# Platform           16719 non-null object
# Year_of_Release    16450 non-null float64
# Genre              16717 non-null object
# Publisher          16665 non-null object
# NA_players         16719 non-null float64
# EU_players         16719 non-null float64
# JP_players         16719 non-null float64
# Other_players      16719 non-null float64
# Global_players     16719 non-null float64
# Critic_Score       8137 non-null float64
# Critic_Count       8137 non-null float64
# User_Score         10015 non-null object
# User_Count         7590 non-null float64
# Developer          10096 non-null object
# Rating             9950 non-null object
# dtypes: float64(9), object(7)
# memory usage: 1.6+ MB

# %%
pplot = sns.pairplot(gamedata)
# Out:
# c:\users\mmitk\appdata\local\programs\python\python37-32\lib\site-packages\numpy\lib\histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# c:\users\mmitk\appdata\local\programs\python\python37-32\lib\site-packages\numpy\lib\histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
gamedata.Genre.unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy', nan], dtype=object)

# %% [markdown]
# Preproccess data, turn discrete string values of Genre and Publisher into numerical values

# %%
from sklearn import preprocessing

# %%
proc_data=gamedata.dropna()#drop nan from gamedata before encoding labels

# %% [markdown]
# Transform Genre Labels into numerical values

# %%
#ge is genre encoder
ge = preprocessing.LabelEncoder()
list_genres=proc_data['Genre']#save list of genres in case needed later
proc_data['Genre']=ge.fit_transform(proc_data['Genre'])
proc_data.head()
# Out:
# c:\users\mmitk\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                     Name Platform  Year_of_Release  Genre Publisher  \
# 0             Wii Sports      Wii           2006.0     10  Nintendo
# 2         Mario Kart Wii      Wii           2008.0      6  Nintendo
# 3      Wii Sports Resort      Wii           2009.0     10  Nintendo
# 6  New Super Mario Bros.       DS           2006.0      4  Nintendo
# 7               Wii Play      Wii           2006.0      3  Nintendo
#
#    NA_players  EU_players  JP_players  Other_players  Global_players  \
# ...

# %% [markdown]
# Now do the same for publisher

# %%
#pe is publisher encoder
pe = preprocessing.LabelEncoder() #create new instance of label encoder
#creating multiple instances for later decoding
list_publishers=proc_data['Publisher']#save list of publishers in case needed later
proc_data['Publisher']=pe.fit_transform(proc_data['Publisher'])
proc_data.head(10)
# Out:
# c:\users\mmitk\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#                          Name Platform  Year_of_Release  Genre  Publisher  \
# 0                  Wii Sports      Wii           2006.0     10        160
# 2              Mario Kart Wii      Wii           2008.0      6        160
# 3           Wii Sports Resort      Wii           2009.0     10        160
# 6       New Super Mario Bros.       DS           2006.0      4        160
# 7                    Wii Play      Wii           2006.0      3        160
# 8   New Super Mario Bros. Wii      Wii           2009.0      4        160
# ...

# %%
#Don't need the name for analysis or predictive model
proc_data=proc_data.drop(columns=['Name'])

# %% [markdown]
# Use label encoder on Platform and Developer and Rating columns as well

# %%
#ple is platform encoder
ple = preprocessing.LabelEncoder() #create new instance of label encoder
#creating multiple instances for later decoding
list_platforms=proc_data['Platform']#save list of Platforms in case needed later
proc_data['Platform']=ple.fit_transform(proc_data['Platform'])

#re is platform encoder
re = preprocessing.LabelEncoder() #create new instance of label encoder
#creating multiple instances for later decoding
list_platforms=proc_data['Rating']#save list of Ratings in case needed later
proc_data['Rating']=re.fit_transform(proc_data['Rating'])

#de is publisher encoder
de = preprocessing.LabelEncoder() #create new instance of label encoder
#creating multiple instances for later decoding
list_publishers=proc_data['Developer']#save list of developers in case needed later
proc_data['Developer']=de.fit_transform(proc_data['Developer'])
proc_data.head(10)
# Out:
#     Platform  Year_of_Release  Genre  Publisher  NA_players  EU_players  \
# 0         12           2006.0     10        160       41.36       28.96
# 2         12           2008.0      6        160       15.68       12.76
# 3         12           2009.0     10        160       15.61       10.93
# 6          2           2006.0      4        160       11.28        9.14
# 7         12           2006.0      3        160       13.96        9.18
# 8         12           2009.0      4        160       14.44        6.94
# 11         2           2005.0      6        160        9.71        7.47
# 13        12           2007.0     10        160        8.92        8.03
# 14        14           2010.0      3        144       15.00        4.89
# 15        12           2009.0     10        160        9.01        8.49
#
#     JP_players  Other_players  Global_players  Critic_Score  Critic_Count  \
# 0         3.77           8.45           82.53          76.0          51.0
# ...

# %% [markdown]
# Now we can view a more meaningful pairplot to analyze the data

# %%
pplot =sns.pairplot(proc_data)

# %% [markdown]
# It is difficult to tell with so many features if theres a relationship between input and output, however there does seem to be an exponential relationship between glopal players and user score, a linear relationship between NA players and global players, as well as EU and global (this is expected, EU and NA are both very large videogame markets and whichevever game has a large following in one likely has a large following in the world). Interestingly there is an exponential relationship between user count and critic rating, two things which one would expect to be fairly independent. There is also a fairly interesting relationship between Japan player count and critic score that seems worth exploring.
